# %% [markdown]
# # Explorando as tabela de careplans, immunizations, observations e procedures

# %% [markdown]
# Leitura dos arquivos .csv de *careplans*, *immunizations*, *procedures* e *observations*, além dos dados de NF e dos arquivos com as *features* definidas através do notebook "features_medications.ipynb". Note que, como os arquivos de observações eram muito grandes para o upload no GitHub, fizemos o upload apenas dos arquivos de observações filtrados por pacientes de interesse (filtragem realizada da mesma forma que será feita para os outros arquivos neste notebook).
#
# As colunas referentes a datas também foram convertidas para *datetime*.

# %%
import pandas as pd
import numpy as np

#Cenário 01

careplans01 = pd.read_csv('https://github.com/caiops/P2_IA368X/raw/main/data/external/scenario01/careplans.csv')
careplans01['START'] = pd.to_datetime(careplans01['START'])
careplans01['STOP'] = pd.to_datetime(careplans01['STOP'])

immunizations01 = pd.read_csv('https://github.com/caiops/P2_IA368X/raw/main/data/external/scenario01/immunizations.csv')
immunizations01['DATE'] = pd.to_datetime(immunizations01['DATE'])

procedures01 = pd.read_csv('https://github.com/caiops/P2_IA368X/raw/main/data/external/scenario01/procedures.csv')
procedures01['START'] = pd.to_datetime(procedures01['START'])
procedures01['STOP'] = pd.to_datetime(procedures01['STOP'])

observations01_i = pd.read_csv('https://github.com/caiops/P2_IA368X/raw/main/data/interim/interest/observations01_i.csv')
observations01_i['DATE'] = pd.to_datetime(observations01_i['DATE'])

scenario01 = pd.read_csv('https://github.com/caiops/P2_IA368X/raw/main/data/interim/features/features_medications_01.csv')
scenario01['BIRTHDATE'] = pd.to_datetime(scenario01['BIRTHDATE'])

nf01 = pd.read_csv('https://github.com/caiops/P2_IA368X/raw/main/data/interim/interest/nf01.csv')
nf01['START'] = pd.to_datetime(nf01['START'])
nf01['STOP'] = pd.to_datetime(nf01['STOP'])

#Cenário 02

careplans02 = pd.read_csv('https://github.com/caiops/P2_IA368X/raw/main/data/external/scenario02/careplans.csv')
careplans02['START'] = pd.to_datetime(careplans02['START'])
careplans02['STOP'] = pd.to_datetime(careplans02['STOP'])

immunizations02 = pd.read_csv('https://github.com/caiops/P2_IA368X/raw/main/data/external/scenario02/immunizations.csv')
immunizations02['DATE'] = pd.to_datetime(immunizations02['DATE'])

procedures02 = pd.read_csv('https://github.com/caiops/P2_IA368X/raw/main/data/external/scenario02/procedures.csv')
procedures02['START'] = pd.to_datetime(procedures02['START'])
procedures02['STOP'] = pd.to_datetime(procedures02['STOP'])

observations02_i = pd.read_csv('https://github.com/caiops/P2_IA368X/raw/main/data/interim/interest/observations02_i.csv')
observations02_i['DATE'] = pd.to_datetime(observations02_i['DATE'])

scenario02 = pd.read_csv('https://github.com/caiops/P2_IA368X/raw/main/data/interim/features/features_medications_02.csv')
scenario02['BIRTHDATE'] = pd.to_datetime(scenario02['BIRTHDATE'])

nf02 = pd.read_csv('https://github.com/caiops/P2_IA368X/raw/main/data/interim/interest/nf02.csv')
nf02['START'] = pd.to_datetime(nf02['START'])
nf02['STOP'] = pd.to_datetime(nf02['STOP'])

# %% [markdown]
# Filtrando os dados de *careplans*, *immunizations* e *procedures* apenas para os pacientes de interesse.

# %%
#Obtendo as listas de pacientes
patients01 = scenario01['PATIENT'].tolist()
patients02 = scenario02['PATIENT'].tolist()
#Obtendo as listas de pacientes de interesse que sobreviveram ou não à NF
death01 = scenario01[scenario01['DEATH_FN'] == 1]['PATIENT'].tolist()
death02 = scenario02[scenario02['DEATH_FN'] == 1]['PATIENT'].tolist()
survive01 = scenario01[scenario01['DEATH_FN'] == 0]['PATIENT'].tolist()
survive02 = scenario02[scenario02['DEATH_FN'] == 0]['PATIENT'].tolist()

# %%
#Obtendo os dados para os pacientes de interesse
#Cenário 01
careplans01_i = careplans01.query('PATIENT in @patients01').copy()
immunizations01_i = immunizations01.query('PATIENT in @patients01').copy()
procedures01_i = procedures01.query('PATIENT in @patients01').copy()
#Cenário 02
careplans02_i = careplans02.query('PATIENT in @patients02').copy()
immunizations02_i = immunizations02.query('PATIENT in @patients02').copy()
procedures02_i = procedures02.query('PATIENT in @patients02').copy()

# %% [markdown]
# ## Observations

# %% [markdown]
# Encontrando os dados de observações cuja data é anterior ou igual à data de início da NF.

# %%
#Mudando as datas das observações do formato data/hora para apenas data, de modo a realizar a comparação seguinte
observations01_i['DATE'] = observations01_i['DATE'].dt.date
observations01_i['DATE'] = pd.to_datetime(observations01_i['DATE'])

observations02_i['DATE'] = observations02_i['DATE'].dt.date
observations02_i['DATE'] = pd.to_datetime(observations02_i['DATE'])

# %%
#Obtendo as observações realizadas antes ou no dia que a NF começou
observations01_i_b = pd.DataFrame(columns=['PATIENT', 'DATE', 'CODE', 'DESCRIPTION', 'VALUE', 'UNITS', 'TYPE'])
for p in patients01:
  date = nf01.loc[nf01['PATIENT'] == p, 'START'].values[0]
  observations01_i_b = pd.concat([observations01_i_b, observations01_i.query('PATIENT == @p & DATE <= @date')[['PATIENT', 'DATE', 'CODE', 'DESCRIPTION', 'VALUE', 'UNITS', 'TYPE']]], ignore_index=True)

display(observations01_i_b)

observations02_i_b = pd.DataFrame(columns=['PATIENT', 'DATE', 'CODE', 'DESCRIPTION', 'VALUE', 'UNITS', 'TYPE'])
for p in patients02:
  date = nf02.loc[nf02['PATIENT'] == p, 'START'].values[0]
  observations02_i_b = pd.concat([observations02_i_b, observations02_i.query('PATIENT == @p & DATE <= @date')[['PATIENT', 'DATE', 'CODE', 'DESCRIPTION', 'VALUE', 'UNITS', 'TYPE']]], ignore_index=True)

display(observations02_i_b)
# Out:
#                                     PATIENT       DATE     CODE  \
# 0      4288f90b-4774-c329-3176-c1482e824c04 2012-06-19   8302-2
# 1      4288f90b-4774-c329-3176-c1482e824c04 2012-06-19  72514-3
# 2      4288f90b-4774-c329-3176-c1482e824c04 2012-06-19  29463-7
# 3      4288f90b-4774-c329-3176-c1482e824c04 2012-06-19  77606-2
# 4      4288f90b-4774-c329-3176-c1482e824c04 2012-06-19   9843-4
# ...                                     ...        ...      ...
# 13572  c815ffa4-2917-2c09-1569-e90d5a89eeb2 1947-06-24  72166-2
# 13573  c815ffa4-2917-2c09-1569-e90d5a89eeb2 1947-06-24  70274-6
# 13574  c815ffa4-2917-2c09-1569-e90d5a89eeb2 1947-06-24  89204-2
# 13575  c815ffa4-2917-2c09-1569-e90d5a89eeb2 1948-05-19    751-8
# 13576  c815ffa4-2917-2c09-1569-e90d5a89eeb2 1948-05-19   8310-5
#
#                                              DESCRIPTION         VALUE  \
# 0                                            Body Height          84.4
# 1      Pain severity - 0-10 verbal numeric rating [Sc...           0.0
# 2                                            Body Weight          10.8
# 3                      Weight-for-length Per age and sex          11.5
# 4                   Head Occipital-frontal circumference          47.6
# ...                                                  ...           ...
# 13572                        Tobacco smoking status NHIS  Never smoker
# 13573  Generalized anxiety disorder 7 item (GAD-7) to...           0.0
# 13574  Patient Health Questionnaire-9: Modified for T...           4.0
# 13575  Neutrophils [#/volume] in Blood by Automated c...         340.5
# 13576                                   Body Temperature         100.6
#
#          UNITS     TYPE
# 0           cm  numeric
# 1      {score}  numeric
# 2           kg  numeric
# 3            %  numeric
# 4           cm  numeric
# ...        ...      ...
# 13572      NaN     text
# 13573  {score}  numeric
# 13574  {score}  numeric
# 13575  10*3/uL  numeric
# 13576   [degF]  numeric
#
# [13577 rows x 7 columns]
#                                     PATIENT       DATE     CODE  \
# 0      bb37561b-ba65-7c47-db5b-0641bca883b4 2012-05-16   8302-2
# 1      bb37561b-ba65-7c47-db5b-0641bca883b4 2012-05-16  72514-3
# 2      bb37561b-ba65-7c47-db5b-0641bca883b4 2012-05-16  29463-7
# 3      bb37561b-ba65-7c47-db5b-0641bca883b4 2012-05-16  77606-2
# 4      bb37561b-ba65-7c47-db5b-0641bca883b4 2012-05-16   9843-4
# ...                                     ...        ...      ...
# 12251  2e3402a9-45ff-3558-8450-375f17107ca0 2016-06-25     QOLS
# 12252  2e3402a9-45ff-3558-8450-375f17107ca0 2017-06-25     QOLS
# 12253  2e3402a9-45ff-3558-8450-375f17107ca0 2018-06-25     QOLS
# 12254  2e3402a9-45ff-3558-8450-375f17107ca0 2019-06-25     QOLS
# 12255  2e3402a9-45ff-3558-8450-375f17107ca0 2020-06-25     QOLS
#
#                                              DESCRIPTION VALUE    UNITS  \
# 0                                            Body Height  64.5       cm
# 1      Pain severity - 0-10 verbal numeric rating [Sc...   1.0  {score}
# 2                                            Body Weight   6.7       kg
# 3                      Weight-for-length Per age and sex  13.0        %
# 4                   Head Occipital-frontal circumference  43.0       cm
# ...                                                  ...   ...      ...
# 12251                                               QOLS   1.0  {score}
# 12252                                               QOLS   1.0  {score}
# 12253                                               QOLS   1.0  {score}
# 12254                                               QOLS   1.0  {score}
# 12255                                               QOLS   1.0  {score}
#
#           TYPE
# 0      numeric
# 1      numeric
# 2      numeric
# 3      numeric
# 4      numeric
# ...        ...
# 12251  numeric
# 12252  numeric
# 12253  numeric
# 12254  numeric
# 12255  numeric
#
# [12256 rows x 7 columns]

# %% [markdown]
# Obtendo a contagem de valores únicos para os identificadores de pacientes e as descrições das observações.

# %%
print('Cenário 01\n')
print('Contagem de observações para cada paciente:')
print(observations01_i_b['PATIENT'].value_counts())
print('\nContagem dos tipos únicos de observações:')
print(observations01_i_b['DESCRIPTION'].value_counts())
print('\nCenário 02\n')
print('Contagem de observações para cada paciente:')
print(observations02_i_b['PATIENT'].value_counts())
print('\nContagem dos tipos únicos de observações:')
print(observations02_i_b['DESCRIPTION'].value_counts())
# Out:
# Cenário 01
#
# Contagem de observações para cada paciente:
# a259d333-6bb2-30f5-ecb9-d5ff168905b0    242
# 6ada49d6-cce2-faea-781d-5f4c282c49b4    232
# 98342e81-23da-dae8-5506-8da094c7d29e    221
# fbb23e67-a3a6-1662-ab90-e9f717c61a97    215
# 9eb99407-b81e-2594-0da2-870e1d88d18c    200
#                                        ...
# c022272d-ecd2-92b6-32f4-3769ef3514f9      5
# 2b7f1733-b575-269e-39d0-a96df81c410d      2
# 03ecc624-4fba-ad89-6a8c-5f197dd1a9fc      2
# 7796fd57-7cb0-c895-5b1a-24dd98001bf0      2
# 27925006-9781-ba3f-19cc-af346d18fde7      2
# Name: PATIENT, Length: 137, dtype: int64
#
# Contagem dos tipos únicos de observações:
# Diastolic Blood Pressure                                         973
# Systolic Blood Pressure                                          973
# Body Weight                                                      958
# Heart rate                                                       958
# Respiratory rate                                                 958
#                                                                 ...
# Percentage area affected by eczema Trunk                           1
# Percentage area affected by eczema Head and Neck                   1
# RBC Auto (Bld) [#/Vol]                                             1
# RDW - Erythrocyte distribution width Auto (RBC) [Entitic vol]      1
# WBC Auto (Bld) [#/Vol]                                             1
# Name: DESCRIPTION, Length: 103, dtype: int64
#
# Cenário 02
#
# Contagem de observações para cada paciente:
# 83b45fe6-567c-aa27-5853-4125ea3d27cf    260
# 8178457c-4eba-11f7-14a1-21b06e02c761    249
# c8c17f8f-5d4d-5f59-0f25-87ae32e6e16a    241
# cd1762bb-df22-3c40-7ff3-6a4b118a4985    224
# 3f3006ef-27bf-6259-6db6-2b87e4b46b24    223
#                                        ...
# 028062c4-4a54-dd30-b166-51641d3ec9fc      8
# 7837ca92-1dc3-b3ef-a7f9-4207e439775c      5
# abe694ea-3597-56a0-df2c-ce8ec0252de4      2
# fd8fcc36-68e9-c3ae-9e6b-f0e023cfac27      2
# 8aa8ae8f-9cde-fee6-26cc-e0fafb499dc5      2
# Name: PATIENT, Length: 117, dtype: int64
#
# Contagem dos tipos únicos de observações:
# Diastolic Blood Pressure                                                                    861
# Systolic Blood Pressure                                                                     861
# Pain severity - 0-10 verbal numeric rating [Score] - Reported                               854
# Body Weight                                                                                 852
# Heart rate                                                                                  852
#                                                                                            ...
# Parainfluenza virus 3 RNA [Presence] in Respiratory specimen by NAA with probe detection      1
# Rhinovirus RNA [Presence] in Respiratory specimen by NAA with probe detection                 1
# Human metapneumovirus RNA [Presence] in Respiratory specimen by NAA with probe detection      1
# Adenovirus A+B+C+D+E DNA [Presence] in Respiratory specimen by NAA with probe detection       1
# SARS-CoV-2 RNA Pnl Resp NAA+probe                                                             1
# Name: DESCRIPTION, Length: 100, dtype: int64

# %% [markdown]
# Chamou nossa atenção as observações do tipo "Neutrophils [#/volume] in Blood by Automated count" e "Body Temperature". Decidimos, então, filtrar as observações realizadas apenas no dia em que se iniciou a NF de cada paciente.

# %%
#Obtendo as observações realizadas no dia que a NF começou
observations01_i_nf = pd.DataFrame(columns=['PATIENT', 'DATE', 'CODE', 'DESCRIPTION', 'VALUE', 'UNITS', 'TYPE'])
for p in patients01:
  date = nf01.loc[nf01['PATIENT'] == p, 'START'].values[0]
  observations01_i_nf = pd.concat([observations01_i_nf, observations01_i.query('PATIENT == @p & DATE == @date')[['PATIENT', 'DATE', 'CODE', 'DESCRIPTION', 'VALUE', 'UNITS', 'TYPE']]], ignore_index=True)

display(observations01_i_nf)

observations02_i_nf = pd.DataFrame(columns=['PATIENT', 'DATE', 'CODE', 'DESCRIPTION', 'VALUE', 'UNITS', 'TYPE'])
for p in patients02:
  date = nf02.loc[nf02['PATIENT'] == p, 'START'].values[0]
  observations02_i_nf = pd.concat([observations02_i_nf, observations02_i.query('PATIENT == @p & DATE == @date')[['PATIENT', 'DATE', 'CODE', 'DESCRIPTION', 'VALUE', 'UNITS', 'TYPE']]], ignore_index=True)

display(observations02_i_nf)
# Out:
#                                   PATIENT       DATE    CODE  \
# 0    4288f90b-4774-c329-3176-c1482e824c04 2012-07-12   751-8
# 1    4288f90b-4774-c329-3176-c1482e824c04 2012-07-12  8310-5
# 2    f03f50be-20b1-3eae-2ed1-bb478bceb320 2018-07-08   751-8
# 3    f03f50be-20b1-3eae-2ed1-bb478bceb320 2018-07-08  8310-5
# 4    11089781-c268-6838-642e-2c2c9edbb694 2020-07-14   751-8
# ..                                    ...        ...     ...
# 421  d5c0cc48-5f8a-4533-325c-25a9c3284185 2020-10-04  8310-5
# 422  eca28495-500f-ab7e-356b-176f31382569 2020-03-02   751-8
# 423  eca28495-500f-ab7e-356b-176f31382569 2020-03-02  8310-5
# 424  c815ffa4-2917-2c09-1569-e90d5a89eeb2 1948-05-19   751-8
# 425  c815ffa4-2917-2c09-1569-e90d5a89eeb2 1948-05-19  8310-5
#
#                                            DESCRIPTION  VALUE    UNITS  \
# 0    Neutrophils [#/volume] in Blood by Automated c...  255.1  10*3/uL
# 1                                     Body Temperature  101.2   [degF]
# 2    Neutrophils [#/volume] in Blood by Automated c...  491.4  10*3/uL
# 3                                     Body Temperature  102.2   [degF]
# 4    Neutrophils [#/volume] in Blood by Automated c...  258.9  10*3/uL
# ..                                                 ...    ...      ...
# 421                                   Body Temperature  101.6   [degF]
# 422  Neutrophils [#/volume] in Blood by Automated c...  425.7  10*3/uL
# 423                                   Body Temperature  100.8   [degF]
# 424  Neutrophils [#/volume] in Blood by Automated c...  340.5  10*3/uL
# 425                                   Body Temperature  100.6   [degF]
#
#         TYPE
# 0    numeric
# 1    numeric
# 2    numeric
# 3    numeric
# 4    numeric
# ..       ...
# 421  numeric
# 422  numeric
# 423  numeric
# 424  numeric
# 425  numeric
#
# [426 rows x 7 columns]
#                                   PATIENT       DATE    CODE  \
# 0    bb37561b-ba65-7c47-db5b-0641bca883b4 2015-02-07   751-8
# 1    bb37561b-ba65-7c47-db5b-0641bca883b4 2015-02-07  8310-5
# 2    678fc07c-1cb1-acc6-3553-d848200626e9 2022-02-07   751-8
# 3    678fc07c-1cb1-acc6-3553-d848200626e9 2022-02-07  8310-5
# 4    04efa71e-b8ed-980b-94a1-cd25e94b6015 2022-04-16   751-8
# ..                                    ...        ...     ...
# 327  7837ca92-1dc3-b3ef-a7f9-4207e439775c 2013-01-08  8310-5
# 328  3f3ad6c2-337b-9d48-47b7-b2197a0a0500 1971-07-18   751-8
# 329  3f3ad6c2-337b-9d48-47b7-b2197a0a0500 1971-07-18  8310-5
# 330  2e3402a9-45ff-3558-8450-375f17107ca0 2021-06-24   751-8
# 331  2e3402a9-45ff-3558-8450-375f17107ca0 2021-06-24  8310-5
#
#                                            DESCRIPTION  VALUE    UNITS  \
# 0    Neutrophils [#/volume] in Blood by Automated c...  406.5  10*3/uL
# 1                                     Body Temperature  102.3   [degF]
# 2    Neutrophils [#/volume] in Blood by Automated c...  265.8  10*3/uL
# 3                                     Body Temperature  101.9   [degF]
# 4    Neutrophils [#/volume] in Blood by Automated c...  496.3  10*3/uL
# ..                                                 ...    ...      ...
# 327                                   Body Temperature  101.1   [degF]
# 328  Neutrophils [#/volume] in Blood by Automated c...  448.6  10*3/uL
# 329                                   Body Temperature  100.8   [degF]
# 330  Neutrophils [#/volume] in Blood by Automated c...  303.6  10*3/uL
# 331                                   Body Temperature  100.8   [degF]
#
#         TYPE
# 0    numeric
# 1    numeric
# 2    numeric
# 3    numeric
# 4    numeric
# ..       ...
# 327  numeric
# 328  numeric
# 329  numeric
# 330  numeric
# 331  numeric
#
# [332 rows x 7 columns]

# %% [markdown]
# Novamente, verificamos a contagem de valores únicos para os identificadores de pacientes e as descrições das observações. Ainda, verificamos o número de vezes que cada paciente apresentou uma observação do tipo "Neutrophils [#/volume] in Blood by Automated count" e "Body Temperature".

# %%
print('Cenário 01\n')
print('Contagem de observações para cada paciente:')
print(observations01_i_nf['PATIENT'].value_counts())
print('\nContagem dos tipos únicos de observações:')
print(observations01_i_nf['DESCRIPTION'].value_counts())
print('\nNúmero de vezes que cada paciente apresentou uma observação da contagem de neutrófilos:')
print(observations01_i_nf.query("DESCRIPTION == 'Neutrophils [#/volume] in Blood by Automated count'")['PATIENT'].value_counts())
print('\nNúmero de vezes que cada paciente apresentou uma observação da temperatura corporal:')
print(observations01_i_nf.query("DESCRIPTION == 'Body Temperature'")['PATIENT'].value_counts())
# Out:
# Cenário 01
#
# Contagem de observações para cada paciente:
# ae5f15a1-427f-ed8c-f258-f25cfb0fd85a    26
# 1cee6029-ca41-7786-fc4f-04aea9778336    26
# 5d3c03b8-74cd-941f-3df6-00c45864f1c2    26
# 77e53fde-d641-fa26-5792-7a92af4fa260    26
# a12fc6b4-938f-9199-2af7-f478c30c1eac    26
#                                         ..
# 7bbcd20f-8d90-2c04-06be-e7918684239f     2
# c9176ee2-d94c-6930-d132-0120cf1eff92     2
# 8a9517bb-bd45-da96-f962-668c905ceecb     2
# 3fe4eb84-cd88-aa94-fa92-e8b6c0858d94     2
# c815ffa4-2917-2c09-1569-e90d5a89eeb2     2
# Name: PATIENT, Length: 117, dtype: int64
#
# Contagem dos tipos únicos de observações:
# Neutrophils [#/volume] in Blood by Automated count                          117
# Body Temperature                                                            117
# DALY                                                                         15
# QALY                                                                         15
# QOLS                                                                         15
# Weight-for-length Per age and sex                                             7
# MCH [Entitic mass] by Automated count                                         7
# Body Height                                                                   7
# Pain severity - 0-10 verbal numeric rating [Score] - Reported                 7
# Tobacco smoking status NHIS                                                   7
# Platelet mean volume [Entitic volume] in Blood by Automated count             7
# Platelet distribution width [Entitic volume] in Blood by Automated count      7
# Platelets [#/volume] in Blood by Automated count                              7
# Erythrocyte distribution width [Entitic volume] by Automated count            7
# MCHC [Mass/volume] by Automated count                                         7
# MCV [Entitic volume] by Automated count                                       7
# Head Occipital-frontal circumference                                          7
# Hematocrit [Volume Fraction] of Blood by Automated count                      7
# Body Weight                                                                   7
# Erythrocytes [#/volume] in Blood by Automated count                           7
# Leukocytes [#/volume] in Blood by Automated count                             7
# Respiratory rate                                                              7
# Heart rate                                                                    7
# Systolic Blood Pressure                                                       7
# Diastolic Blood Pressure                                                      7
# Hemoglobin [Mass/volume] in Blood                                             7
# Name: DESCRIPTION, dtype: int64
#
# Número de vezes que cada paciente apresentou uma observação da contagem de neutrófilos:
# 4288f90b-4774-c329-3176-c1482e824c04    1
# 7c2d7821-5781-20ff-1b7d-9c0b48d02151    1
# 26088591-b65b-938c-8ce0-edb6cf52ab7c    1
# 84483a05-0e7c-cc01-7ef7-83e93da36d92    1
# 4b8877ac-d142-dbf4-f1e0-06c638ab66c9    1
#                                        ..
# cfe7cd0f-57de-4f43-d870-221bba80520b    1
# 114f35cc-db2d-65d7-678b-18495e4e6473    1
# 2ca78a43-6d05-52e7-d149-607acb760c03    1
# e90e1bfc-18af-2b1b-e4a2-c4fc60d8e18a    1
# c815ffa4-2917-2c09-1569-e90d5a89eeb2    1
# Name: PATIENT, Length: 117, dtype: int64
#
# Número de vezes que cada paciente apresentou uma observação da temperatura corporal:
# 4288f90b-4774-c329-3176-c1482e824c04    1
# 7c2d7821-5781-20ff-1b7d-9c0b48d02151    1
# 26088591-b65b-938c-8ce0-edb6cf52ab7c    1
# 84483a05-0e7c-cc01-7ef7-83e93da36d92    1
# 4b8877ac-d142-dbf4-f1e0-06c638ab66c9    1
#                                        ..
# cfe7cd0f-57de-4f43-d870-221bba80520b    1
# 114f35cc-db2d-65d7-678b-18495e4e6473    1
# 2ca78a43-6d05-52e7-d149-607acb760c03    1
# e90e1bfc-18af-2b1b-e4a2-c4fc60d8e18a    1
# c815ffa4-2917-2c09-1569-e90d5a89eeb2    1
# Name: PATIENT, Length: 117, dtype: int64

# %%
print('Cenário 02\n')
print('Contagem de observações para cada paciente:')
print(observations02_i_nf['PATIENT'].value_counts())
print('\nContagem dos tipos únicos de observações:')
print(observations02_i_nf['DESCRIPTION'].value_counts())
print('\nNúmero de vezes que cada paciente apresentou uma observação da contagem de neutrófilos:')
print(observations02_i_nf.query("DESCRIPTION == 'Neutrophils [#/volume] in Blood by Automated count'")['PATIENT'].value_counts())
print('\nNúmero de vezes que cada paciente apresentou uma observação da temperatura corporal:')
print(observations02_i_nf.query("DESCRIPTION == 'Body Temperature'")['PATIENT'].value_counts())
# Out:
# Cenário 02
#
# Contagem de observações para cada paciente:
# 243d3ef4-0fb2-edb0-441f-45b5701bf2db    26
# 10545fda-0b7f-f479-a9eb-a50534aba634    26
# 38a5661c-416a-08e9-6aed-3bccb151e7e4    26
# 3ad364dd-9b86-0a69-3a14-4323f141a630     5
# 0dc670fe-5d98-e434-d1f6-4f253535f817     5
#                                         ..
# 7011f231-ff8e-2605-61da-de2f2d86c68a     2
# f4cd1424-0a65-96d3-e184-56b02e74398f     2
# c3a6a691-c2b9-a81e-3b0e-46362af0d52e     2
# 81865e6e-7ce5-f2a9-202f-220bf23a3947     2
# 2e3402a9-45ff-3558-8450-375f17107ca0     2
# Name: PATIENT, Length: 112, dtype: int64
#
# Contagem dos tipos únicos de observações:
# Neutrophils [#/volume] in Blood by Automated count                          112
# Body Temperature                                                            112
# QALY                                                                         15
# DALY                                                                         15
# QOLS                                                                         15
# Erythrocytes [#/volume] in Blood by Automated count                           3
# Platelet mean volume [Entitic volume] in Blood by Automated count             3
# Platelet distribution width [Entitic volume] in Blood by Automated count      3
# Platelets [#/volume] in Blood by Automated count                              3
# Erythrocyte distribution width [Entitic volume] by Automated count            3
# MCHC [Mass/volume] by Automated count                                         3
# MCH [Entitic mass] by Automated count                                         3
# MCV [Entitic volume] by Automated count                                       3
# Hematocrit [Volume Fraction] of Blood by Automated count                      3
# Hemoglobin [Mass/volume] in Blood                                             3
# Respiratory rate                                                              3
# Leukocytes [#/volume] in Blood by Automated count                             3
# Heart rate                                                                    3
# Systolic Blood Pressure                                                       3
# Diastolic Blood Pressure                                                      3
# Head Occipital-frontal circumference                                          3
# Weight-for-length Per age and sex                                             3
# Body Weight                                                                   3
# Pain severity - 0-10 verbal numeric rating [Score] - Reported                 3
# Body Height                                                                   3
# Tobacco smoking status NHIS                                                   3
# Name: DESCRIPTION, dtype: int64
#
# Número de vezes que cada paciente apresentou uma observação da contagem de neutrófilos:
# bb37561b-ba65-7c47-db5b-0641bca883b4    1
# 678fc07c-1cb1-acc6-3553-d848200626e9    1
# 6b17b083-39c0-f107-e905-ee89ad02d0ed    1
# 1ac16be4-9c27-bc83-e3cb-1ea35040406f    1
# 5d102f9f-543b-d0bc-e509-6887faddb0da    1
#                                        ..
# f4cd1424-0a65-96d3-e184-56b02e74398f    1
# c3a6a691-c2b9-a81e-3b0e-46362af0d52e    1
# 81865e6e-7ce5-f2a9-202f-220bf23a3947    1
# f4b28b81-0c49-d919-8a75-a7a8912d5556    1
# 2e3402a9-45ff-3558-8450-375f17107ca0    1
# Name: PATIENT, Length: 112, dtype: int64
#
# Número de vezes que cada paciente apresentou uma observação da temperatura corporal:
# bb37561b-ba65-7c47-db5b-0641bca883b4    1
# 678fc07c-1cb1-acc6-3553-d848200626e9    1
# 6b17b083-39c0-f107-e905-ee89ad02d0ed    1
# 1ac16be4-9c27-bc83-e3cb-1ea35040406f    1
# 5d102f9f-543b-d0bc-e509-6887faddb0da    1
#                                        ..
# f4cd1424-0a65-96d3-e184-56b02e74398f    1
# c3a6a691-c2b9-a81e-3b0e-46362af0d52e    1
# 81865e6e-7ce5-f2a9-202f-220bf23a3947    1
# f4b28b81-0c49-d919-8a75-a7a8912d5556    1
# 2e3402a9-45ff-3558-8450-375f17107ca0    1
# Name: PATIENT, Length: 112, dtype: int64

# %% [markdown]
# Investigamos quantas vezes foram reportadas observações de contagem de neutrófilos e da temperatura corporal considerando todas as datas anteriores ou iguais ao início da NF.

# %%
print('Cenário 01\n')
print('Número de observações da contagem de neutrófilos:')
print(observations01_i_b['DESCRIPTION'].value_counts()['Neutrophils [#/volume] in Blood by Automated count'])
print('\nNúmero de observações da temperatura corporal:')
print(observations01_i_b['DESCRIPTION'].value_counts()['Body Temperature'])

print('\nCenário 02\n')
print('Número de observações da contagem de neutrófilos:')
print(observations02_i_b['DESCRIPTION'].value_counts()['Neutrophils [#/volume] in Blood by Automated count'])
print('\nNúmero de observações da temperatura corporal:')
print(observations02_i_b['DESCRIPTION'].value_counts()['Body Temperature'])
# Out:
# Cenário 01
#
# Número de observações da contagem de neutrófilos:
# 117
#
# Número de observações da temperatura corporal:
# 117
#
# Cenário 02
#
# Número de observações da contagem de neutrófilos:
# 112
#
# Número de observações da temperatura corporal:
# 112

# %% [markdown]
# Os números de observações é igual considerando datas inferiores ou iguais ao início da NF e considerando apenas a data de início da NF. Ou seja, observações desse tipo não foram realizadas antes do diagnóstico da NF.
#
# No entanto, acabamos notando que, sem a imposição do limite relacionado à data de inicio da NF, todos os pacientes de interesse apresentaram as observações de contagem de neutrófilos e temperatura corporal.

# %%
print('Cenário 01:\n')
print('Número de vezes que cada paciente apresentou uma observação da contagem de neutrófilos, desconsiderando a data limite:')
print(observations01_i.query("DESCRIPTION == 'Neutrophils [#/volume] in Blood by Automated count'")['PATIENT'].value_counts())
print('\nNúmero de vezes que cada paciente apresentou uma observação da temperatura corporal, desconsiderando a data limite:')
print(observations01_i.query("DESCRIPTION == 'Body Temperature'")['PATIENT'].value_counts())

print('\nCenário 02:\n')
print('Número de vezes que cada paciente apresentou uma observação da contagem de neutrófilos, desconsiderando a data limite:')
print(observations02_i.query("DESCRIPTION == 'Neutrophils [#/volume] in Blood by Automated count'")['PATIENT'].value_counts())
print('\nNúmero de vezes que cada paciente apresentou uma observação da temperatura corporal, desconsiderando a data limite:')
print(observations02_i.query("DESCRIPTION == 'Body Temperature'")['PATIENT'].value_counts())
# Out:
# Cenário 01:
#
# Número de vezes que cada paciente apresentou uma observação da contagem de neutrófilos, desconsiderando a data limite:
# 4288f90b-4774-c329-3176-c1482e824c04    1
# ee42b995-8fc5-d8bf-5c09-205408bb76fd    1
# e7e52291-59e3-52f1-310c-a232fd7be114    1
# 0ecf6b43-7c73-0458-ab56-19de89acf41e    1
# 49bd843b-b75e-ac60-a452-605e324c9df2    1
#                                        ..
# e90e1bfc-18af-2b1b-e4a2-c4fc60d8e18a    1
# 2dfb6d26-2f71-ecc5-6b9d-ea20dc1ae490    1
# a259d333-6bb2-30f5-ecb9-d5ff168905b0    1
# a12fc6b4-938f-9199-2af7-f478c30c1eac    1
# c815ffa4-2917-2c09-1569-e90d5a89eeb2    1
# Name: PATIENT, Length: 139, dtype: int64
#
# Número de vezes que cada paciente apresentou uma observação da temperatura corporal, desconsiderando a data limite:
# 4288f90b-4774-c329-3176-c1482e824c04    1
# ee42b995-8fc5-d8bf-5c09-205408bb76fd    1
# e7e52291-59e3-52f1-310c-a232fd7be114    1
# 0ecf6b43-7c73-0458-ab56-19de89acf41e    1
# 49bd843b-b75e-ac60-a452-605e324c9df2    1
#                                        ..
# e90e1bfc-18af-2b1b-e4a2-c4fc60d8e18a    1
# 2dfb6d26-2f71-ecc5-6b9d-ea20dc1ae490    1
# a259d333-6bb2-30f5-ecb9-d5ff168905b0    1
# a12fc6b4-938f-9199-2af7-f478c30c1eac    1
# c815ffa4-2917-2c09-1569-e90d5a89eeb2    1
# Name: PATIENT, Length: 139, dtype: int64
#
# Cenário 02:
#
# Número de vezes que cada paciente apresentou uma observação da contagem de neutrófilos, desconsiderando a data limite:
# bb37561b-ba65-7c47-db5b-0641bca883b4    1
# fe9e8ecf-79e1-545d-a28b-26274781bd97    1
# 3edd7198-2494-cc95-d844-ab3a3adb562f    1
# 6b17b083-39c0-f107-e905-ee89ad02d0ed    1
# 1ac16be4-9c27-bc83-e3cb-1ea35040406f    1
#                                        ..
# c3a6a691-c2b9-a81e-3b0e-46362af0d52e    1
# 81865e6e-7ce5-f2a9-202f-220bf23a3947    1
# f4b28b81-0c49-d919-8a75-a7a8912d5556    1
# 33469efc-5b9a-e5fe-a3be-b99e946395d3    1
# 2e3402a9-45ff-3558-8450-375f17107ca0    1
# Name: PATIENT, Length: 117, dtype: int64
#
# Número de vezes que cada paciente apresentou uma observação da temperatura corporal, desconsiderando a data limite:
# bb37561b-ba65-7c47-db5b-0641bca883b4    1
# fe9e8ecf-79e1-545d-a28b-26274781bd97    1
# 3edd7198-2494-cc95-d844-ab3a3adb562f    1
# 6b17b083-39c0-f107-e905-ee89ad02d0ed    1
# 1ac16be4-9c27-bc83-e3cb-1ea35040406f    1
#                                        ..
# c3a6a691-c2b9-a81e-3b0e-46362af0d52e    1
# 81865e6e-7ce5-f2a9-202f-220bf23a3947    1
# f4b28b81-0c49-d919-8a75-a7a8912d5556    1
# 33469efc-5b9a-e5fe-a3be-b99e946395d3    1
# 2e3402a9-45ff-3558-8450-375f17107ca0    1
# Name: PATIENT, Length: 117, dtype: int64

# %% [markdown]
# Assim, decidimos descartar o limite de data relacionado ao início da NF, de modo que todos os pacientes de interesse possuam valores para as observações de contagem de neutrófilos e de temperatura corporal.
#
# Verificamos, então, algumas estatísticas descritivas básicas para os valores observados da contagem de neutrófilos e da temperatura corporal.

# %%
#Valores observados para a contagem de neutrófilos e para a temperatura corporal (cenário 01)
neut01 = observations01_i.query("DESCRIPTION == 'Neutrophils [#/volume] in Blood by Automated count'")[['PATIENT', 'VALUE']]
bt01 = observations01_i.query("DESCRIPTION == 'Body Temperature'")[['PATIENT', 'VALUE']]

#Valores observados para a contagem de neutrófilos e para a temperatura corporal (cenário 02)
neut02 = observations02_i.query("DESCRIPTION == 'Neutrophils [#/volume] in Blood by Automated count'")[['PATIENT', 'VALUE']]
bt02 = observations02_i.query("DESCRIPTION == 'Body Temperature'")[['PATIENT', 'VALUE']]

print('Cenário 01\n')
print('Estatísticas descritivas básicas para os valores observados da contagem de neutrófilos:')
print(pd.to_numeric(neut01['VALUE']).describe())
print('\nEstatísticas descritivas básicas para os valores observados da temperatura corporal:')
print(pd.to_numeric(bt01['VALUE']).describe())

print('\nCenário 02\n')
print('Estatísticas descritivas básicas para os valores observados da contagem de neutrófilos:')
print(pd.to_numeric(neut02['VALUE']).describe())
print('\nEstatísticas descritivas básicas para os valores observados da temperatura corporal:')
print(pd.to_numeric(bt02['VALUE']).describe())
# Out:
# Cenário 01
#
# Estatísticas descritivas básicas para os valores observados da contagem de neutrófilos:
# count    139.000000
# mean     380.464748
# std       71.293141
# min      252.800000
# 25%      323.500000
# 50%      378.800000
# 75%      439.600000
# max      497.700000
# Name: VALUE, dtype: float64
#
# Estatísticas descritivas básicas para os valores observados da temperatura corporal:
# count    139.000000
# mean     101.720863
# std        0.790934
# min      100.400000
# 25%      101.000000
# 50%      101.800000
# 75%      102.350000
# max      103.000000
# Name: VALUE, dtype: float64
#
# Cenário 02
#
# Estatísticas descritivas básicas para os valores observados da contagem de neutrófilos:
# count    117.000000
# mean     378.173504
# std       70.403090
# min      250.600000
# 25%      324.400000
# 50%      374.100000
# 75%      441.400000
# max      499.900000
# Name: VALUE, dtype: float64
#
# Estatísticas descritivas básicas para os valores observados da temperatura corporal:
# count    117.000000
# mean     101.723932
# std        0.785060
# min      100.400000
# 25%      101.100000
# 50%      101.700000
# 75%      102.400000
# max      103.000000
# Name: VALUE, dtype: float64

# %% [markdown]
# Por fim, acrescentamos os valores das observações nas tabelas de *features*.

# %%
#Acrescentando os valores das observações da contagem de neutrófilos e da temperatura corporal nas tabelas pro orange:
scenario01 = scenario01.merge(neut01, on='PATIENT', how='left')
scenario01.rename(columns={"VALUE":"NEUT_CONT"}, inplace=True)

scenario01 = scenario01.merge(bt01, on='PATIENT', how='left')
scenario01.rename(columns={"VALUE":"BODY_TEMP_F"}, inplace=True)

display(scenario01)

scenario02 = scenario02.merge(neut02, on='PATIENT', how='left')
scenario02.rename(columns={"VALUE":"NEUT_CONT"}, inplace=True)

scenario02 = scenario02.merge(bt02, on='PATIENT', how='left')
scenario02.rename(columns={"VALUE":"BODY_TEMP_F"}, inplace=True)

display(scenario02)
# Out:
#                                   PATIENT  BIRTHDATE   RACE    ETHNICITY  \
# 0    4288f90b-4774-c329-3176-c1482e824c04 2010-07-13  white  nonhispanic
# 1    f03f50be-20b1-3eae-2ed1-bb478bceb320 2002-07-12  white  nonhispanic
# 2    11089781-c268-6838-642e-2c2c9edbb694 2011-07-17  white  nonhispanic
# 3    d7b9725d-889f-d178-cf41-dbf8b373eda9 2010-10-18  black  nonhispanic
# 4    ed2bb6aa-1f3c-b72b-46a6-54f05cac7da7 2008-04-09  asian  nonhispanic
# ..                                    ...        ...    ...          ...
# 134  7d87bdff-2df1-8162-80e4-2e406304515d 2011-06-17  white  nonhispanic
# 135  d5c0cc48-5f8a-4533-325c-25a9c3284185 2017-10-05  other  nonhispanic
# 136  a4cabcbc-8282-5599-6b69-01e28e69c045 2004-09-24  black  nonhispanic
# 137  eca28495-500f-ab7e-356b-176f31382569 2017-03-03  white  nonhispanic
# 138  c815ffa4-2917-2c09-1569-e90d5a89eeb2 1933-05-23  white  nonhispanic
#
#     GENDER  DEATH_FN  AGE_FN_YEARS  BACTEREMIA  WELLNESS_CONT  \
# 0        M         0             2           0            1.0
# 1        M         0            16           1            6.0
# 2        F         0             9           0           12.0
# 3        F         0             6           0            7.0
# 4        M         0            12           0            7.0
# ..     ...       ...           ...         ...            ...
# 134      M         0             2           0            4.0
# 135      F         0             3           1           11.0
# 136      M         0            16           0            8.0
# 137      F         0             3           0           11.0
# 138      M         1            15           0            9.0
#
#      AMBULATORY_SYMPTOM_CONT  MED_AMLD NEUT_CONT BODY_TEMP_F
# 0                        0.0         0     255.1       101.2
# 1                        1.0         1     491.4       102.2
# 2                        2.0         0     258.9       102.0
# 3                        1.0         0     360.7       102.9
# 4                        2.0         0     364.6       100.6
# ..                       ...       ...       ...         ...
# 134                      0.0         0     479.1       101.0
# 135                      1.0         1     476.6       101.6
# 136                      0.0         0     364.4       101.5
# 137                      0.0         0     425.7       100.8
# 138                      7.0         0     340.5       100.6
#
# [139 rows x 13 columns]
#                                   PATIENT  BIRTHDATE   RACE    ETHNICITY  \
# 0    bb37561b-ba65-7c47-db5b-0641bca883b4 2012-02-08  white  nonhispanic
# 1    678fc07c-1cb1-acc6-3553-d848200626e9 2006-02-11  white  nonhispanic
# 2    04efa71e-b8ed-980b-94a1-cd25e94b6015 2018-04-17  other  nonhispanic
# 3    1e466cbc-5018-4c1a-b132-cf8a4a4d87cf 1997-02-18  white  nonhispanic
# 4    8e9d1dd0-085f-a629-3ea6-9033f330b383 1996-03-07  white  nonhispanic
# ..                                    ...        ...    ...          ...
# 112  84c9e441-fa88-33c8-5d87-91b863998d26 1944-08-04  white  nonhispanic
# 113  7837ca92-1dc3-b3ef-a7f9-4207e439775c 1996-01-13  white  nonhispanic
# 114  3f3ad6c2-337b-9d48-47b7-b2197a0a0500 1969-07-18  white  nonhispanic
# 115  32d8410a-cc4b-4d8b-601d-3ad2b8ef912b 2006-08-23  white  nonhispanic
# 116  2e3402a9-45ff-3558-8450-375f17107ca0 2016-06-25  white  nonhispanic
#
#     GENDER  DEATH_FN  AGE_FN_YEARS  BACTEREMIA  WELLNESS_CONT  \
# 0        M         0             3           0            9.0
# 1        F         0            16           0            9.0
# 2        F         0             4           0           13.0
# 3        F         0            21           1            4.0
# 4        F         0            20           1            3.0
# ..     ...       ...           ...         ...            ...
# 112      F         1             2           1            9.0
# 113      M         0            17           0           15.0
# 114      F         1             2           1            9.0
# 115      M         0             9           0            8.0
# 116      M         0             5           1           14.0
#
#      AMBULATORY_SYMPTOM_CONT  MED_AMLD NEUT_CONT BODY_TEMP_F
# 0                        1.0         0     406.5       102.3
# 1                        2.0         0     265.8       101.9
# 2                        2.0         0     496.3       101.7
# 3                       10.0         0     321.7       101.8
# 4                        1.0         0     460.9       103.0
# ..                       ...       ...       ...         ...
# 112                      1.0         0     250.6       100.9
# 113                      2.0         0     435.9       101.1
# 114                      0.0         1     448.6       100.8
# 115                      4.0         0     391.1       102.0
# 116                      2.0         0     303.6       100.8
#
# [117 rows x 13 columns]

# %% [markdown]
# ## Immunizations

# %% [markdown]
# Encontrando os dados de imunização cuja data é anterior ou igual à data de início da NF.

# %%
#Mudando as datas das imunizações do formato data/hora para apenas data, de modo a realizar a comparação seguinte
immunizations01_i['DATE'] = immunizations01_i['DATE'].dt.date
immunizations01_i['DATE'] = pd.to_datetime(immunizations01_i['DATE'])

immunizations02_i['DATE'] = immunizations02_i['DATE'].dt.date
immunizations02_i['DATE'] = pd.to_datetime(immunizations02_i['DATE'])

# %%
#Obtendo as imunizações realizadas antes ou no dia que a NF começou
immunizations01_i_b = pd.DataFrame(columns=['PATIENT', 'DATE', 'DESCRIPTION'])
for p in patients01:
  date = nf01.loc[nf01['PATIENT'] == p, 'START'].values[0]
  immunizations01_i_b = pd.concat([immunizations01_i_b, immunizations01_i.query('PATIENT == @p & DATE <= @date')[['PATIENT', 'DATE', 'DESCRIPTION']]], ignore_index=True)

display(immunizations01_i_b)

immunizations02_i_b = pd.DataFrame(columns=['PATIENT', 'DATE', 'DESCRIPTION'])
for p in patients02:
  date = nf02.loc[nf02['PATIENT'] == p, 'START'].values[0]
  immunizations02_i_b = pd.concat([immunizations02_i_b, immunizations02_i.query('PATIENT == @p & DATE <= @date')[['PATIENT', 'DATE', 'DESCRIPTION']]], ignore_index=True)

display(immunizations02_i_b)
# Out:
#                                    PATIENT       DATE  \
# 0     4288f90b-4774-c329-3176-c1482e824c04 2012-06-19
# 1     f03f50be-20b1-3eae-2ed1-bb478bceb320 2012-07-20
# 2     f03f50be-20b1-3eae-2ed1-bb478bceb320 2013-07-26
# 3     f03f50be-20b1-3eae-2ed1-bb478bceb320 2013-07-26
# 4     f03f50be-20b1-3eae-2ed1-bb478bceb320 2013-07-26
# ...                                    ...        ...
# 1565  eca28495-500f-ab7e-356b-176f31382569 2019-08-09
# 1566  eca28495-500f-ab7e-356b-176f31382569 2020-02-07
# 1567  c815ffa4-2917-2c09-1569-e90d5a89eeb2 1945-06-12
# 1568  c815ffa4-2917-2c09-1569-e90d5a89eeb2 1946-06-18
# 1569  c815ffa4-2917-2c09-1569-e90d5a89eeb2 1947-06-24
#
#                                             DESCRIPTION
# 0     Influenza  seasonal  injectable  preservative ...
# 1     Influenza  seasonal  injectable  preservative ...
# 2                                                  Tdap
# 3     Influenza  seasonal  injectable  preservative ...
# 4                                     HPV  quadrivalent
# ...                                                 ...
# 1565                            Hep A  ped/adol  2 dose
# 1566  Influenza  seasonal  injectable  preservative ...
# 1567  Influenza  seasonal  injectable  preservative ...
# 1568  Influenza  seasonal  injectable  preservative ...
# 1569  Influenza  seasonal  injectable  preservative ...
#
# [1570 rows x 3 columns]
#                                    PATIENT       DATE  \
# 0     bb37561b-ba65-7c47-db5b-0641bca883b4 2012-05-16
# 1     bb37561b-ba65-7c47-db5b-0641bca883b4 2012-05-16
# 2     bb37561b-ba65-7c47-db5b-0641bca883b4 2012-05-16
# 3     bb37561b-ba65-7c47-db5b-0641bca883b4 2012-05-16
# 4     bb37561b-ba65-7c47-db5b-0641bca883b4 2012-05-16
# ...                                    ...        ...
# 1481  2e3402a9-45ff-3558-8450-375f17107ca0 2021-06-05
# 1482  2e3402a9-45ff-3558-8450-375f17107ca0 2021-06-05
# 1483  2e3402a9-45ff-3558-8450-375f17107ca0 2021-06-05
# 1484  2e3402a9-45ff-3558-8450-375f17107ca0 2021-06-05
# 1485  2e3402a9-45ff-3558-8450-375f17107ca0 2021-06-05
#
#                                             DESCRIPTION
# 0                                         Hib (PRP-OMP)
# 1                                 rotavirus  monovalent
# 2                                                   IPV
# 3                                                  DTaP
# 4                         Pneumococcal conjugate PCV 13
# ...                                                 ...
# 1481                                          varicella
# 1482                                                IPV
# 1483  Influenza  seasonal  injectable  preservative ...
# 1484                                               DTaP
# 1485                                                MMR
#
# [1486 rows x 3 columns]

# %% [markdown]
# Obtendo a contagem de valores únicos para os identificadores de pacientes e as descrições das imunizações.

# %%
print('Cenário 01\n')
print('Contagem de imunizações para cada paciente:')
print(immunizations01_i_b['PATIENT'].value_counts())
print('\nContagem dos tipos únicos de imunizações:')
print(immunizations01_i_b['DESCRIPTION'].value_counts())
print('\nCenário 02\n')
print('Contagem de imunizações para cada paciente:')
print(immunizations02_i_b['PATIENT'].value_counts())
print('\nContagem dos tipos únicos de imunizações:')
print(immunizations02_i_b['DESCRIPTION'].value_counts())
# Out:
# Cenário 01
#
# Contagem de imunizações para cada paciente:
# fbb23e67-a3a6-1662-ab90-e9f717c61a97    34
# 6884a50b-2060-67ff-0863-51569e687cc2    32
# 0f652e34-7595-a919-5856-50e0d6258699    32
# d1fe5a74-fd5a-4651-4b55-2985bc8288ea    32
# f0f510b2-9888-120a-a693-bcaca0f937cd    32
#                                         ..
# cfe7cd0f-57de-4f43-d870-221bba80520b     1
# 7bbcd20f-8d90-2c04-06be-e7918684239f     1
# ae5f15a1-427f-ed8c-f258-f25cfb0fd85a     1
# 99bfcaff-0b03-90da-dad5-b23fcc28fb61     1
# 4288f90b-4774-c329-3176-c1482e824c04     1
# Name: PATIENT, Length: 124, dtype: int64
#
# Contagem dos tipos únicos de imunizações:
# Influenza  seasonal  injectable  preservative free                                               449
# DTaP                                                                                             171
# IPV                                                                                              166
# Pneumococcal conjugate PCV 13                                                                    143
# Hib (PRP-OMP)                                                                                    135
# Hep B  adolescent or pediatric                                                                   131
# Hep A  ped/adol  2 dose                                                                           73
# rotavirus  monovalent                                                                             71
# MMR                                                                                               65
# varicella                                                                                         62
# HPV  quadrivalent                                                                                 49
# meningococcal MCV4P                                                                               29
# Tdap                                                                                              17
# Hep B  adult                                                                                       5
# SARS-COV-2 (COVID-19) vaccine  mRNA  spike protein  LNP  preservative free  30 mcg/0.3mL dose      4
# Name: DESCRIPTION, dtype: int64
#
# Cenário 02
#
# Contagem de imunizações para cada paciente:
# c8c17f8f-5d4d-5f59-0f25-87ae32e6e16a    35
# 8178457c-4eba-11f7-14a1-21b06e02c761    35
# 3f3006ef-27bf-6259-6db6-2b87e4b46b24    34
# 86b7c6c8-d523-17ca-38d8-a40ff92ffffd    33
# 70c119f4-92d4-a341-a924-a11f5d0ab51f    33
#                                         ..
# eba28f1d-1db0-e1a8-9f7f-33cdf61c8af2     1
# a1462169-9a8a-2090-f8ba-5a156f097e35     1
# 243d3ef4-0fb2-edb0-441f-45b5701bf2db     1
# 38a5661c-416a-08e9-6aed-3bccb151e7e4     1
# cea409fe-95a2-abd4-52ff-f7b6b0402c89     1
# Name: PATIENT, Length: 112, dtype: int64
#
# Contagem dos tipos únicos de imunizações:
# Influenza  seasonal  injectable  preservative free    418
# DTaP                                                  175
# IPV                                                   166
# Pneumococcal conjugate PCV 13                         149
# Hib (PRP-OMP)                                         123
# Hep B  adolescent or pediatric                        123
# rotavirus  monovalent                                  74
# MMR                                                    67
# Hep A  ped/adol  2 dose                                67
# varicella                                              59
# HPV  quadrivalent                                      31
# meningococcal MCV4P                                    24
# Tdap                                                   10
# Name: DESCRIPTION, dtype: int64

# %% [markdown]
# ## Procedures

# %% [markdown]
# Encontrando os dados de procedimentos cuja data inicial é anterior ou igual à data de início da NF.

# %%
#Mudando as datas iniciais dos procedimentos do formato data/hora para apenas data, de modo a realizar a comparação seguinte
procedures01_i['START'] = procedures01_i['START'].dt.date
procedures01_i['START'] = pd.to_datetime(procedures01_i['START'])

procedures02_i['START'] = procedures02_i['START'].dt.date
procedures02_i['START'] = pd.to_datetime(procedures02_i['START'])

# %%
#Obtendo os procedimentos realizados antes ou no dia que a NF começou
procedures01_i_b = pd.DataFrame(columns=['PATIENT', 'START', 'CODE', 'DESCRIPTION', 'REASONCODE', 'REASONDESCRIPTION'])
for p in patients01:
  date = nf01.loc[nf01['PATIENT'] == p, 'START'].values[0]
  procedures01_i_b = pd.concat([procedures01_i_b, procedures01_i.query('PATIENT == @p & START <= @date')[['PATIENT', 'START', 'CODE', 'DESCRIPTION', 'REASONCODE', 'REASONDESCRIPTION']]], ignore_index=True)

display(procedures01_i_b)

procedures02_i_b = pd.DataFrame(columns=['PATIENT', 'START', 'CODE', 'DESCRIPTION', 'REASONCODE', 'REASONDESCRIPTION'])
for p in patients02:
  date = nf02.loc[nf02['PATIENT'] == p, 'START'].values[0]
  procedures02_i_b = pd.concat([procedures02_i_b, procedures02_i.query('PATIENT == @p & START <= @date')[['PATIENT', 'START', 'CODE', 'DESCRIPTION', 'REASONCODE', 'REASONDESCRIPTION']]], ignore_index=True)

display(procedures02_i_b)
# Out:
#                                    PATIENT      START             CODE  \
# 0     4288f90b-4774-c329-3176-c1482e824c04 2012-06-19        430193006
# 1     4288f90b-4774-c329-3176-c1482e824c04 2012-07-12        367336001
# 2     4288f90b-4774-c329-3176-c1482e824c04 2012-07-12        449214001
# 3     f03f50be-20b1-3eae-2ed1-bb478bceb320 2012-07-20        430193006
# 4     f03f50be-20b1-3eae-2ed1-bb478bceb320 2013-01-02         63332003
# ...                                    ...        ...              ...
# 2549  c815ffa4-2917-2c09-1569-e90d5a89eeb2 1947-06-24  428211000124100
# 2550  c815ffa4-2917-2c09-1569-e90d5a89eeb2 1947-06-24        868187001
# 2551  c815ffa4-2917-2c09-1569-e90d5a89eeb2 1947-06-24        386516004
# 2552  c815ffa4-2917-2c09-1569-e90d5a89eeb2 1948-05-19        367336001
# 2553  c815ffa4-2917-2c09-1569-e90d5a89eeb2 1948-05-19         16983000
#
#                                             DESCRIPTION  REASONCODE  \
# 0                 Medication Reconciliation (procedure)         NaN
# 1                              Chemotherapy (procedure)  91861009.0
# 2                                  Transfer to stepdown  91861009.0
# 3                 Medication Reconciliation (procedure)         NaN
# 4          History AND physical examination (procedure)         NaN
# ...                                                 ...         ...
# 2549            Assessment of substance use (procedure)         NaN
# 2550  Assessment using Car  Relax  Alone  Forget  Fr...         NaN
# 2551                  Anticipatory guidance (procedure)         NaN
# 2552                           Chemotherapy (procedure)  91861009.0
# 2553                          Death in hospital (event)  91861009.0
#
#                                REASONDESCRIPTION
# 0                                            NaN
# 1     Acute myeloid leukemia  disease (disorder)
# 2     Acute myeloid leukemia  disease (disorder)
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 2549                                         NaN
# 2550                                         NaN
# 2551                                         NaN
# 2552  Acute myeloid leukemia  disease (disorder)
# 2553  Acute myeloid leukemia  disease (disorder)
#
# [2554 rows x 6 columns]
#                                    PATIENT      START       CODE  \
# 0     bb37561b-ba65-7c47-db5b-0641bca883b4 2012-05-16  430193006
# 1     bb37561b-ba65-7c47-db5b-0641bca883b4 2012-10-17  430193006
# 2     bb37561b-ba65-7c47-db5b-0641bca883b4 2013-04-11  313191000
# 3     bb37561b-ba65-7c47-db5b-0641bca883b4 2013-04-29  395142003
# 4     bb37561b-ba65-7c47-db5b-0641bca883b4 2014-07-16  430193006
# ...                                    ...        ...        ...
# 1971  2e3402a9-45ff-3558-8450-375f17107ca0 2021-06-13    1225002
# 1972  2e3402a9-45ff-3558-8450-375f17107ca0 2021-06-13  274474001
# 1973  2e3402a9-45ff-3558-8450-375f17107ca0 2021-06-24  367336001
# 1974  2e3402a9-45ff-3558-8450-375f17107ca0 2021-06-24  305351004
# 1975  2e3402a9-45ff-3558-8450-375f17107ca0 2021-06-24  449214001
#
#                                 DESCRIPTION   REASONCODE  \
# 0     Medication Reconciliation (procedure)          NaN
# 1     Medication Reconciliation (procedure)          NaN
# 2                   Injection of adrenaline          NaN
# 3                    Allergy screening test          NaN
# 4     Medication Reconciliation (procedure)          NaN
# ...                                     ...          ...
# 1971                        Upper arm X-ray          NaN
# 1972                    Bone immobilization   65966004.0
# 1973               Chemotherapy (procedure)   91861009.0
# 1974     Admit to intensive care unit (ICU)  409089005.0
# 1975                   Transfer to stepdown   91861009.0
#
#                                REASONDESCRIPTION
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 1971                                         NaN
# 1972                         Fracture of forearm
# 1973  Acute myeloid leukemia  disease (disorder)
# 1974              Febrile neutropenia (disorder)
# 1975  Acute myeloid leukemia  disease (disorder)
#
# [1976 rows x 6 columns]

# %% [markdown]
# Obtendo a contagem de valores únicos para os identificadores de pacientes e as descrições dos procedimentos.

# %%
print('Cenário 01\n')
print('Contagem de procedimentos para cada paciente:')
print(procedures01_i_b['PATIENT'].value_counts())
print('\nContagem dos tipos únicos de procedimentos:')
print(procedures01_i_b['DESCRIPTION'].value_counts())
print('\nCenário 02\n')
print('Contagem de procedimentos para cada paciente:')
print(procedures02_i_b['PATIENT'].value_counts())
print('\nContagem dos tipos únicos de procedimentos:')
print(procedures02_i_b['DESCRIPTION'].value_counts())
# Out:
# Cenário 01
#
# Contagem de procedimentos para cada paciente:
# fcacc452-c0ff-6fbe-c8b7-4b77e3807232    403
# 98342e81-23da-dae8-5506-8da094c7d29e    168
# f03f50be-20b1-3eae-2ed1-bb478bceb320    138
# 28911653-c9ef-e5a8-61a5-668dbb48f58f    109
# a259d333-6bb2-30f5-ecb9-d5ff168905b0    106
#                                        ...
# adf63106-46a4-e19c-349a-f0a3eec09e33      2
# 7796fd57-7cb0-c895-5b1a-24dd98001bf0      2
# 331b91fb-bca6-ab76-2671-1bf22def011e      2
# 1cee6029-ca41-7786-fc4f-04aea9778336      2
# d1fe5a74-fd5a-4651-4b55-2985bc8288ea      1
# Name: PATIENT, Length: 137, dtype: int64
#
# Contagem dos tipos únicos de procedimentos:
# Medication Reconciliation (procedure)                        419
# Nursing care/supplementary surveillance (regime/therapy)     165
# Physical therapy procedure (regime/therapy)                  156
# Occupational therapy (regime/therapy)                        154
# Chemotherapy (procedure)                                     120
#                                                             ...
# Seizure Count Cerebral Cortex Electroencephalogram (EEG)       1
# Care regimes assessment (procedure)                            1
# Peripheral blood smear interpretation                          1
# Intravenous blood transfusion of packed cells (procedure)      1
# Insertion of intrauterine contraceptive device                 1
# Name: DESCRIPTION, Length: 99, dtype: int64
#
# Cenário 02
#
# Contagem de procedimentos para cada paciente:
# 2e3402a9-45ff-3558-8450-375f17107ca0    135
# cd1762bb-df22-3c40-7ff3-6a4b118a4985    119
# c622620c-2687-a641-eabe-286ed4692265    101
# 1e466cbc-5018-4c1a-b132-cf8a4a4d87cf     94
# 33dda6d1-bc76-060b-77c4-e278d1a93291     90
#                                        ...
# 420233c9-8b17-3505-56ee-4a36659faf13      2
# fd8fcc36-68e9-c3ae-9e6b-f0e023cfac27      2
# 7837ca92-1dc3-b3ef-a7f9-4207e439775c      2
# 8aa8ae8f-9cde-fee6-26cc-e0fafb499dc5      2
# 243d3ef4-0fb2-edb0-441f-45b5701bf2db      2
# Name: PATIENT, Length: 117, dtype: int64
#
# Contagem dos tipos únicos de procedimentos:
# Medication Reconciliation (procedure)     381
# Subcutaneous immunotherapy                161
# Chemotherapy (procedure)                  112
# Depression screening (procedure)          100
# Transfer to stepdown                       99
#                                          ...
# Referral to hypertension clinic             1
# Care regimes assessment (procedure)         1
# Oromotor Exercises                          1
# Posture training (procedure)                1
# Surgical manipulation of joint of knee      1
# Name: DESCRIPTION, Length: 100, dtype: int64

# %% [markdown]
# Considerando apenas os procedimentos realizados em razão da "Acute myeloid leukemia disease (disorder)".

# %%
print('Contagem de procedimentos realizados por paciente em razão do câncer (cenário 01):')
procedures01_i_b.loc[procedures01_i_b["REASONCODE"]== 91861009, 'PATIENT'].value_counts()
# Out:
# Contagem de procedimentos realizados por paciente em razão do câncer (cenário 01):
# 4288f90b-4774-c329-3176-c1482e824c04    2
# f03f50be-20b1-3eae-2ed1-bb478bceb320    2
# 84483a05-0e7c-cc01-7ef7-83e93da36d92    2
# 4b8877ac-d142-dbf4-f1e0-06c638ab66c9    2
# adf63106-46a4-e19c-349a-f0a3eec09e33    2
#                                        ..
# 2dfb6d26-2f71-ecc5-6b9d-ea20dc1ae490    2
# c815ffa4-2917-2c09-1569-e90d5a89eeb2    2
# 738a5bc6-78c7-2b05-d185-9741920b0497    1
# 0b7f4569-6127-edae-6b43-3ba8469a21dc    1
# 47c2ab95-1569-1afa-4550-ac83d53f0384    1
# Name: PATIENT, Length: 120, dtype: int64

# %%
print('Contagem de procedimentos realizados por paciente em razão do câncer (cenário 02):')
procedures02_i_b.loc[procedures02_i_b["REASONCODE"]== 91861009, 'PATIENT'].value_counts()
# Out:
# Contagem de procedimentos realizados por paciente em razão do câncer (cenário 02):
# bb37561b-ba65-7c47-db5b-0641bca883b4    2
# 678fc07c-1cb1-acc6-3553-d848200626e9    2
# 6b17b083-39c0-f107-e905-ee89ad02d0ed    2
# 1ac16be4-9c27-bc83-e3cb-1ea35040406f    2
# 5d102f9f-543b-d0bc-e509-6887faddb0da    2
#                                        ..
# f4cd1424-0a65-96d3-e184-56b02e74398f    2
# c3a6a691-c2b9-a81e-3b0e-46362af0d52e    2
# 81865e6e-7ce5-f2a9-202f-220bf23a3947    2
# f4b28b81-0c49-d919-8a75-a7a8912d5556    2
# 2e3402a9-45ff-3558-8450-375f17107ca0    2
# Name: PATIENT, Length: 112, dtype: int64

# %% [markdown]
# Notamos que, considerando a data limite relacionada ao início da NF, nem todos os pacientes apresentaram procedimentos relacionados ao diagnóstico de câncer. No entanto, desconsiderando essa data limite, foi possível obter dados para todos os pacientes.
#
# Obtendo os procedimentos realizados em razão da "Acute myeloid leukemia disease (disorder)", desconsiderando a data limite.

# %%
#Cenário 01
amld01 = procedures01_i.query('REASONCODE == 91861009')
display(amld01)
#Cenário 02
amld02 = procedures02_i.query('REASONCODE == 91861009')
display(amld02)
# Out:
#             START                      STOP  \
# 670    2012-07-12 2012-07-12 14:37:25+00:00
# 95072  Acute myeloid leukemia  disease (disorder)
# 95209  Acute myeloid leukemia  disease (disorder)
# 95210  Acute myeloid leukemia  disease (disorder)
# 95453  Acute myeloid leukemia  disease (disorder)
# 95455  Acute myeloid leukemia  disease (disorder)
#
# [234 rows x 9 columns]

# %%
print('Contagem de procedimentos realizados por paciente em razão do câncer, desconsiderando a data limite (cenário 01):')
amld01['PATIENT'].value_counts()
# Out:
# Contagem de procedimentos realizados por paciente em razão do câncer, desconsiderando a data limite (cenário 01):
# 4288f90b-4774-c329-3176-c1482e824c04    2
# ee42b995-8fc5-d8bf-5c09-205408bb76fd    2
# e7e52291-59e3-52f1-310c-a232fd7be114    2
# 0ecf6b43-7c73-0458-ab56-19de89acf41e    2
# 49bd843b-b75e-ac60-a452-605e324c9df2    2
#                                        ..
# e90e1bfc-18af-2b1b-e4a2-c4fc60d8e18a    2
# 2dfb6d26-2f71-ecc5-6b9d-ea20dc1ae490    2
# a259d333-6bb2-30f5-ecb9-d5ff168905b0    2
# a12fc6b4-938f-9199-2af7-f478c30c1eac    2
# c815ffa4-2917-2c09-1569-e90d5a89eeb2    2
# Name: PATIENT, Length: 139, dtype: int64

# %%
print('Contagem de procedimentos realizados por paciente em razão do câncer, desconsiderando a data limite (cenário 02):')
amld02['PATIENT'].value_counts()
# Out:
# Contagem de procedimentos realizados por paciente em razão do câncer, desconsiderando a data limite (cenário 02):
# bb37561b-ba65-7c47-db5b-0641bca883b4    2
# fe9e8ecf-79e1-545d-a28b-26274781bd97    2
# 3edd7198-2494-cc95-d844-ab3a3adb562f    2
# 6b17b083-39c0-f107-e905-ee89ad02d0ed    2
# 1ac16be4-9c27-bc83-e3cb-1ea35040406f    2
#                                        ..
# c3a6a691-c2b9-a81e-3b0e-46362af0d52e    2
# 81865e6e-7ce5-f2a9-202f-220bf23a3947    2
# f4b28b81-0c49-d919-8a75-a7a8912d5556    2
# 33469efc-5b9a-e5fe-a3be-b99e946395d3    2
# 2e3402a9-45ff-3558-8450-375f17107ca0    2
# Name: PATIENT, Length: 117, dtype: int64

# %% [markdown]
# Ainda, cada paciente apresentou exatamente dois procedimentos relacionados ao câncer.
#
# Verificamos, então, os tipos de procedimentos.

# %%
print('Tipos diferentes de procedimentos (cenário 01):')
print(amld01['DESCRIPTION'].value_counts())
print('\nTipos diferentes de procedimentos (cenário 02):')
amld02['DESCRIPTION'].value_counts()
# Out:
# Tipos diferentes de procedimentos (cenário 01):
# Chemotherapy (procedure)     139
# Transfer to stepdown         113
# Death in hospital (event)     26
# Name: DESCRIPTION, dtype: int64
#
# Tipos diferentes de procedimentos (cenário 02):
# Chemotherapy (procedure)     117
# Transfer to stepdown         104
# Death in hospital (event)     13
# Name: DESCRIPTION, dtype: int64

# %%
print('Contagem de vezes que cada paciente fez quimioterapia (cenário 01):')
print(amld01.loc[amld01['DESCRIPTION'] == 'Chemotherapy (procedure)', 'PATIENT'].value_counts())

print('\nContagem de vezes que cada paciente fez quimioterapia (cenário 02):')
print(amld02.loc[amld02['DESCRIPTION'] == 'Chemotherapy (procedure)', 'PATIENT'].value_counts())
# Out:
# Contagem de vezes que cada paciente fez quimioterapia (cenário 01):
# 4288f90b-4774-c329-3176-c1482e824c04    1
# ee42b995-8fc5-d8bf-5c09-205408bb76fd    1
# e7e52291-59e3-52f1-310c-a232fd7be114    1
# 0ecf6b43-7c73-0458-ab56-19de89acf41e    1
# 49bd843b-b75e-ac60-a452-605e324c9df2    1
#                                        ..
# e90e1bfc-18af-2b1b-e4a2-c4fc60d8e18a    1
# 2dfb6d26-2f71-ecc5-6b9d-ea20dc1ae490    1
# a259d333-6bb2-30f5-ecb9-d5ff168905b0    1
# a12fc6b4-938f-9199-2af7-f478c30c1eac    1
# c815ffa4-2917-2c09-1569-e90d5a89eeb2    1
# Name: PATIENT, Length: 139, dtype: int64
#
# Contagem de vezes que cada paciente fez quimioterapia (cenário 02):
# bb37561b-ba65-7c47-db5b-0641bca883b4    1
# fe9e8ecf-79e1-545d-a28b-26274781bd97    1
# 3edd7198-2494-cc95-d844-ab3a3adb562f    1
# 6b17b083-39c0-f107-e905-ee89ad02d0ed    1
# 1ac16be4-9c27-bc83-e3cb-1ea35040406f    1
#                                        ..
# c3a6a691-c2b9-a81e-3b0e-46362af0d52e    1
# 81865e6e-7ce5-f2a9-202f-220bf23a3947    1
# f4b28b81-0c49-d919-8a75-a7a8912d5556    1
# 33469efc-5b9a-e5fe-a3be-b99e946395d3    1
# 2e3402a9-45ff-3558-8450-375f17107ca0    1
# Name: PATIENT, Length: 117, dtype: int64

# %% [markdown]
# É interessante notar que, como o esperado, todos os pacientes que tiveram NF fizeram quimioterapia. Ainda, o número de pacientes que morreram no hospital foi igual ao número de pacientes que morreram com NF que obtivemos nas análises anteriores.

# %% [markdown]
# ## Careplans

# %% [markdown]
# Verificando as diferentes razões para os "careplans" e sua contagem.

# %%
print('Cenário 01:')
print(careplans01_i['REASONDESCRIPTION'].value_counts())

print('\nCenário 02:')
print(careplans02_i['REASONDESCRIPTION'].value_counts())
# Out:
# Cenário 01:
# Concussion with no loss of consciousness        12
# Sprain of ankle                                 11
# Hypertension                                    11
# Childhood asthma                                10
# Sprain of wrist                                  8
# Fracture of ankle                                6
# Laceration of hand                               5
# Fracture of forearm                              5
# Atopic dermatitis                                5
# Second degree burn                               4
# Laceration of thigh                              4
# Laceration of forearm                            4
# Prediabetes                                      3
# Concussion with loss of consciousness            3
# Fracture of clavicle                             3
# Fracture subluxation of wrist                    3
# Laceration of foot                               3
# Concussion injury of brain                       2
# First degree burn                                2
# Facial laceration                                2
# Closed fracture of hip                           2
# Injury of medial collateral ligament of knee     1
# Chronic obstructive bronchitis (disorder)        1
# Fracture of rib                                  1
# Tear of meniscus of knee                         1
# Escherichia coli urinary tract infection         1
# Name: REASONDESCRIPTION, dtype: int64
#
# Cenário 02:
# Childhood asthma                                14
# Hypertension                                    10
# Sprain of ankle                                  9
# Fracture of clavicle                             7
# Atopic dermatitis                                7
# Sprain of wrist                                  6
# Concussion with no loss of consciousness         5
# Laceration of forearm                            5
# Fracture subluxation of wrist                    5
# Fracture of forearm                              4
# Fracture of ankle                                3
# Laceration of thigh                              3
# Laceration of hand                               3
# Laceration of foot                               3
# Second degree burn                               3
# Concussion with loss of consciousness            2
# Tear of meniscus of knee                         1
# Escherichia coli urinary tract infection         1
# Cystitis                                         1
# Fracture of rib                                  1
# First degree burn                                1
# Prediabetes                                      1
# Injury of medial collateral ligament of knee     1
# Name: REASONDESCRIPTION, dtype: int64

# %% [markdown]
# Verificando as diferentes descrições para os "careplans" e sua contagem.

# %%
print('Cenário 01:')
print(careplans01_i['DESCRIPTION'].value_counts())

print('\nCenário 02:')
print(careplans02_i['DESCRIPTION'].value_counts())
# Out:
# Cenário 01:
# Respiratory therapy                                               69
# Routine antenatal care                                            26
# Physiotherapy care plan (record artifact)                         25
# Self-care interventions (procedure)                               25
# Fracture care                                                     20
# Infectious disease care plan (record artifact)                    18
# Wound care                                                        18
# Head injury rehabilitation                                        17
# Therapy (regime/therapy)                                          12
# Musculoskeletal care                                              12
# Lifestyle education regarding hypertension                        11
# Asthma self management                                            10
# Overactivity/inattention behavior management                       7
# Weight management program                                          6
# Burn care                                                          6
# Skin condition care                                                5
# Allergic disorder monitoring                                       4
# Diabetes self management plan                                      3
# Chronic obstructive pulmonary disease clinical management plan     1
# Minor surgery care management (procedure)                          1
# Urinary tract infection care                                       1
# Name: DESCRIPTION, dtype: int64
#
# Cenário 02:
# Respiratory therapy                               59
# Self-care interventions (procedure)               24
# Fracture care                                     20
# Physiotherapy care plan (record artifact)         17
# Wound care                                        14
# Infectious disease care plan (record artifact)    14
# Asthma self management                            14
# Routine antenatal care                            13
# Lifestyle education regarding hypertension        10
# Allergic disorder monitoring                       8
# Overactivity/inattention behavior management       8
# Head injury rehabilitation                         7
# Skin condition care                                7
# Therapy (regime/therapy)                           7
# Burn care                                          4
# Musculoskeletal care                               3
# Urinary tract infection care                       2
# Weight management program                          1
# Diabetes self management plan                      1
# Name: DESCRIPTION, dtype: int64

# %% [markdown]
# Verificando o número de pacientes que passaram por terapia respiratória (careplan que mais apareceu).

# %%
print('Cenário 01:')
rt01 = careplans01_i.loc[careplans01_i['DESCRIPTION'] == 'Respiratory therapy']
print(rt01['PATIENT'].value_counts())
print('Número de pacientes: ', len(rt01['PATIENT'].value_counts()))

print('\nCenário 02:')
rt02 = careplans02_i.loc[careplans02_i['DESCRIPTION'] == 'Respiratory therapy']
print(rt02['PATIENT'].value_counts())
print('Número de pacientes: ', len(rt02['PATIENT'].value_counts()))
# Out:
# Cenário 01:
# 8288abe0-04e8-ee34-c028-535da273c3dd    3
# 11d7ecb8-1e4b-ff44-ff40-80755767512c    3
# 6ada49d6-cce2-faea-781d-5f4c282c49b4    3
# 1e92bf63-416b-c43a-fab1-7b25599ac247    2
# 61c56ab4-d429-19d3-6eb8-be4021a8f96f    2
# f05e62cc-d39b-c0a4-4cda-7af990fafd7f    2
# a259d333-6bb2-30f5-ecb9-d5ff168905b0    2
# 160a53cf-63b1-790d-5e95-307e88c1dc9c    2
# a08eb05d-46f4-c6cf-feeb-b0ac56f61458    2
# 11c85df9-4085-afce-75ba-3e62f0c77609    2
# eabfa666-29b5-64f3-105a-e8ea7653ae70    1
# 7c2d7821-5781-20ff-1b7d-9c0b48d02151    1
# 3fa732a0-cdca-c427-6c38-2afa3f4b2369    1
# 99bfcaff-0b03-90da-dad5-b23fcc28fb61    1
# 0ecf6b43-7c73-0458-ab56-19de89acf41e    1
# 32d8410a-cc4b-4d8b-601d-3ad2b8ef912b    2
# 5429227f-c53f-74a3-2636-1a19fc58c4ac    2
# cea409fe-95a2-abd4-52ff-f7b6b0402c89    2
# 4e11fddc-9e90-5da5-3685-c01d0efb8542    1
# bf17b3d6-8405-672d-3685-a0a78ad7b4ec    1
# 6b17b083-39c0-f107-e905-ee89ad02d0ed    1
# 1ede9f9d-ba2b-7e4c-dc7d-6e461139250c    1
# 03edc846-5e5d-00d6-e7a5-7e687f084b40    1
# 3b71c71e-a941-014d-b2b1-71a4b8d80c1d    1
# 3a0500f6-a2fc-7092-a406-f0622ac3a61b    1
# e36a494a-1a8a-2029-edd9-1b2f768232ba    1
# 420233c9-8b17-3505-56ee-4a36659faf13    1
# 4907e10f-4a61-2ea0-598a-633faa36da2c    1
# f100ec51-5788-6bbc-a99a-a710500de6ae    1
# f3c141cf-3c2a-df1b-0be7-71d0e1b0506d    1
# 02ad7d05-1836-3305-e941-c94e79d4283b    1
# 33dda6d1-bc76-060b-77c4-e278d1a93291    1
# 243d3ef4-0fb2-edb0-441f-45b5701bf2db    1
# 1748fa10-1d91-69e5-bc0f-2b4041712e11    1
# 3f3006ef-27bf-6259-6db6-2b87e4b46b24    1
# 485e1481-6b29-0b93-d96f-efc9fa3d2c5f    1
# e3dc2754-0b44-08f0-daa3-25dcaef3709d    1
# 73bce5aa-52fc-9101-e1f1-a80e84447b25    1
# ea652b8e-8d60-007e-b861-0086ead314ef    1
# 0b33cdec-f69f-d533-1841-cff1c3cc17dc    1
# 430cd3b5-d230-f7f7-925e-4a5318da09cd    1
# 31c1ab33-80b5-d97b-2cb3-b88cad539e7d    1
# 1b89ae9b-abcd-689f-eea1-298026950beb    1
# e28969c1-cc28-2b27-9424-ffa59d85d673    1
# d8fbb6b0-e632-b596-3923-815158308c82    1
# e1b08886-e93d-ff5b-5c80-dacbbd8375c0    1
# f5625e35-e54f-9614-cf5e-2d284fd6baed    1
# 7191d0ae-428f-da64-469a-82e9fb352db6    1
# 83b45fe6-567c-aa27-5853-4125ea3d27cf    1
# cd1762bb-df22-3c40-7ff3-6a4b118a4985    1
# Name: PATIENT, dtype: int64
# Número de pacientes:  45

# %% [markdown]
# Verificando o número de pacientes que passaram por terapia respiratória até o dia que a NF começou.

# %%
#Obtendo os careplans do tipo terapia respiratoria realizados antes ou no dia que a NF começou
rt01_b = pd.DataFrame(columns=['PATIENT', 'START', 'CODE', 'DESCRIPTION', 'REASONCODE', 'REASONDESCRIPTION'])
for p in patients01:
  date = nf01.loc[nf01['PATIENT'] == p, 'START'].values[0]
  rt01_b = pd.concat([rt01_b, rt01.query('PATIENT == @p & START <= @date')[['PATIENT', 'START', 'CODE', 'DESCRIPTION', 'REASONCODE', 'REASONDESCRIPTION']]], ignore_index=True)

display(rt01_b)

rt02_b = pd.DataFrame(columns=['PATIENT', 'START', 'CODE', 'DESCRIPTION', 'REASONCODE', 'REASONDESCRIPT
#             DESCRIPTION REASONCODE REASONDESCRIPTION
# 0   Respiratory therapy        NaN               NaN
# 1   Respiratory therapy        NaN               NaN
# 2   Respiratory therapy        NaN               NaN
# 3   Respiratory therapy        NaN               NaN
# 4   Respiratory therapy        NaN               NaN
# 5   Respiratory therapy        NaN               NaN
# 6   Respiratory therapy        NaN               NaN
# 7   Respiratory therapy        NaN               NaN
# 8   Respiratory therapy        NaN               NaN
# 9   Respiratory therapy        NaN               NaN
# 10  Respiratory therapy        NaN               NaN
# 11  Respiratory therapy        NaN               NaN
# 12  Respiratory therapy        NaN               NaN
# 13  Respiratory therapy        NaN               NaN
# 14  Respiratory therapy        NaN               NaN
# 15  Respiratory therapy        NaN               NaN
# 16  Respiratory therapy        NaN               NaN
# 17  Respiratory therapy        NaN               NaN
# 18  Respiratory therapy        NaN               NaN
# 19  Respiratory therapy        NaN               NaN
# 20  Respiratory therapy        NaN               NaN
# 21  Respiratory therapy        NaN               NaN
# 22  Respiratory therapy        NaN               NaN
# 23  Respiratory therapy        NaN               NaN
# 24  Respiratory therapy        NaN               NaN
# 25  Respiratory therapy        NaN               NaN
# 26  Respiratory therapy        NaN               NaN
# 27  Respiratory therapy        NaN               NaN
# 28  Respiratory therapy        NaN               NaN
# 29  Respiratory therapy        NaN               NaN
# 30  Respiratory therapy        NaN               NaN
# 31  Respiratory therapy        NaN               NaN
# 32  Respiratory therapy        NaN               NaN
# 33  Respiratory therapy        NaN               NaN
# 34  Respiratory therapy        NaN               NaN
# 35  Respiratory therapy        NaN               NaN
# 36  Respiratory therapy        NaN               NaN
#                                  PATIENT      START      CODE  \
# 0   0b33cdec-f69f-d533-1841-cff1c3cc17dc 2014-02-14  53950000
# 1   bf17b3d6-8405-672d-3685-a0a78ad7b4ec 2020-09-03  53950000
# 2   5429227f-c53f-74a3-2636-1a19fc58c4ac 2012-12-04  53950000
# 3   3f3006ef-27bf-6259-6db6-2b87e4b46b24 2019-09-19  53950000
# 4   73bce5aa-52fc-9101-e1f1-a80e84447b25 1994-04-19  53950000
# 5   83b45fe6-567c-aa27-5853-4125ea3d27cf 2017-03-01  53950000
# 6   f4cd1424-0a65-96d3-e184-56b02e74398f 2016-10-21  53950000
# 7   7191d0ae-428f-da64-469a-82e9fb352db6 2018-05-20  53950000
# 8   f5625e35-e54f-9614-cf5e-2d284fd6baed 2014-01-24  53950000
# 9   e28969c1-cc28-2b27-9424-ffa59d85d673 2017-07-28  53950000
# 10  cd1762bb-df22-3c40-7ff3-6a4b118a4985 2014-12-23  53950000
# 11  0abb2932-da50-ba64-cc11-c24e1fb1da05 2014-11-10  53950000
# 12  a519942f-78b5-f321-1824-b36cdcde170c 1993-06-19  53950000
# 13  1748fa10-1d91-69e5-bc0f-2b4041712e11 1977-08-09  53950000
# 14  3edd7198-2494-cc95-d844-ab3a3adb562f 2013-01-08  53950000
# 15  3edd7198-2494-cc95-d844-ab3a3adb562f 2014-12-31  53950000
# 16  3edd7198-2494-cc95-d844-ab3a3adb562f 2017-08-09  53950000
# 17  33dda6d1-bc76-060b-77c4-e278d1a93291 2019-03-22  53950000
# 18  32d8410a-cc4b-4d8b-601d-3ad2b8ef912b 2013-08-19  53950000
#
#             DESCRIPTION REASONCODE REASONDESCRIPTION
# 0   Respiratory therapy        NaN               NaN
# 1   Respiratory therapy        NaN               NaN
# 2   Respiratory therapy        NaN               NaN
# 3   Respiratory therapy        NaN               NaN
# 4   Respiratory therapy        NaN               NaN
# 5   Respiratory therapy        NaN               NaN
# 6   Respiratory therapy        NaN               NaN
# 7   Respiratory therapy        NaN               NaN
# 8   Respiratory therapy        NaN               NaN
# 9   Respiratory therapy        NaN               NaN
# 10  Respiratory therapy        NaN               NaN
# 11  Respiratory therapy        NaN               NaN
# 12  Respiratory therapy        NaN               NaN
# 13  Respiratory therapy        NaN               NaN
# 14  Respiratory therapy        NaN               NaN
# 15  Respiratory therapy        NaN               NaN
# 16  Respiratory therapy        NaN               NaN
# 17  Respiratory therapy        NaN               NaN
# 18  Respiratory therapy        NaN               NaN

# %%
print('Cenário 01:')
rt01_b_c = rt01_b['PATIENT'].value_counts().reset_index()
rt01_b_c.columns = ['PATIENT', 'RT_CONT']
display(rt01_b_c)
print('Número de pacientes: ', len(rt01_b_c))

print('\nCenário 02:')
rt02_b_c = rt02_b['PATIENT'].value_counts().reset_index()
rt02_b_c.columns = ['PATIENT', 'RT_CONT']
display(rt02_b_c)
print('Número de pacientes: ', len(rt02_b_c))
# Out:
# Cenário 01:
#                                  PATIENT  RT_CONT
# 0   6ada49d6-cce2-faea-781d-5f4c282c49b4        3
# 1   160a53cf-63b1-790d-5e95-307e88c1dc9c        2
# 2   8288abe0-04e8-ee34-c028-535da273c3dd        2
# 3   11089781-c268-6838-642e-2c2c9edbb694        1
# 4   63f9799b-e770-b92d-d74e-d57609cd775e        1
# 5   721e493e-23b3-af08-8571-54b20617f159        1
# 6   05313452-3962-82d9-60a2-cd79e464cc80        1
# 7   dd902384-4955-83d4-4b52-7909f0f91e51        1
# 8   11d7ecb8-1e4b-ff44-ff40-80755767512c        1
# 9   eabfa666-29b5-64f3-105a-e8ea7653ae70        1
# 10  0ecf6b43-7c73-0458-ab56-19de89acf41e        1
# 11  4b115fe6-e241-6571-e959-e9340b298d75        1
# 12  dd5328d0-4c53-d310-8411-2d3a7fa5ed58        1
# 13  f05e62cc-d39b-c0a4-4cda-7af990fafd7f        1
# 14  70a574b3-eddf-abcb-9a64-1e6e27d13f02        1
# 15  65f05f7c-2de0-d736-fb91-2876c2ef2014        1
# 16  9d8eda02-9d9e-6f08-f840-bf52e8722946        1
# 17  7cc73fa5-9d65-b03d-e139-4e348017b92f        1
# 18  fbb23e67-a3a6-1662-ab90-e9f717c61a97        1
# 19  d7b9725d-889f-d178-cf41-dbf8b373eda9        1
# 20  ccecb758-0a9b-9670-23e6-9e405f69a690        1
# 21  3075db0f-918e-3d24-0782-5b359d23e357        1
# 22  a259d333-6bb2-30f5-ecb9-d5ff168905b0        1
# 23  009c30e1-5fa4-f50c-dfa5-bf3092116bbb        1
# 24  af0d6b3e-9631-827d-6651-7565821260e2        1
